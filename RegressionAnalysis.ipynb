# %% [markdown]
# #HomeWork 2 - CS 483 Data Mining                                           (Resham Jhangiani)

# %% [markdown]
# ## Loading the Housing dataset into a data frame

# %%
import pandas as pd

df = pd.read_csv('https://raw.githubusercontent.com/rasbt/'
                 'python-machine-learning-book-2nd-edition'
                 '/master/code/ch10/housing.data.txt',
                 header=None,
                 sep='\s+')

df.columns = ['CRIM', 'ZN', 'INDUS', 'CHAS', 
              'NOX', 'RM', 'AGE', 'DIS', 'RAD', 
              'TAX', 'PTRATIO', 'B', 'LSTAT', 'MEDV']
df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296.0
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242.0
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242.0
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222.0
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222.0
#
#    PTRATIO       B  LSTAT  MEDV
# 0     15.3  396.90   4.98  24.0
# 1     17.8  396.90   9.14  21.6
# 2     17.8  392.83   4.03  34.7
# 3     18.7  394.63   2.94  33.4
# 4     18.7  396.90   5.33  36.2

# %% [markdown]
# <br>
# <br>

# %% [raw]
# ### Load the Boston dataset as pandas data frame. Seperate out the target MEDV into a different pandas dataframe.

# %%
import statsmodels.api as sm
from sklearn import datasets ## imports datasets from scikit-learn
data = datasets.load_boston() ## loads Boston dataset from datasets library 

import numpy as np
import pandas as pd
# define the data/predictors as the pre-set feature names  
df = pd.DataFrame(data.data, columns=data.feature_names)

# Put the target (housing value -- MEDV) in another DataFrame
target = pd.DataFrame(data.target, columns=["MEDV"])

# %% [markdown]
# ## Linear Regression Model input label=RM, output prediction=MEDV

# %% [markdown]
# ### Visualizing the important characteristics of a dataset

# %%
import matplotlib.pyplot as plt
import numpy as np
X = df['RM']
Y = target['MEDV']
plt.scatter(X, Y)
plt.xlabel("RM")
plt.ylabel("MEDV")
plt.legend(loc='upper left')
plt.show()

# %% [markdown]
# <br>
# <br>

# %% [raw]
# ### Training the Ordinary Least Square model to predict MEDV on input parameter RM - Linear Regression

# %%
import statsmodels.api as sm

X = df["RM"]
y = target["MEDV"]

# Note the difference in argument order
model = sm.OLS(y, X).fit()
predictions = model.predict(X) # make the predictions by the model

# Print out the statistics
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                   MEDV   R-squared:                       0.901
# Model:                            OLS   Adj. R-squared:                  0.901
# Method:                 Least Squares   F-statistic:                     4615.
# Date:                Thu, 25 Oct 2018   Prob (F-statistic):          3.74e-256
# Time:                        13:15:40   Log-Likelihood:                -1747.1
# No. Observations:                 506   AIC:                             3496.
# Df Residuals:                     505   BIC:                             3500.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# RM             3.6534      0.054     67.930      0.000       3.548       3.759
# ...

# %% [raw]
# Plot the Linear Regression model with Statsmodel

# %%
plt.scatter(X, y, c='grey', edgecolor='white', s=70)
plt.xlabel('True Values')
plt.ylabel('Predictions')
plt.plot(X, predictions, color='black')

# %%
from sklearn.linear_model import LinearRegression

# %%
X = df[['RM']]
y = target['MEDV']

slr = LinearRegression()
slr.fit(X, y)
y_pred = slr.predict(X)
print('Slope: %.3f' % slr.coef_[0])
print('Intercept: %.3f' % slr.intercept_)
# Out:
# Slope: 9.102
# Intercept: -34.671

# %%
plt.scatter(X, y, c='steelblue', edgecolor='white', s=70)
plt.plot(X, y_pred, color='black', lw=2)    
plt.xlabel('(Average number of rooms) True Values RM')
plt.ylabel('(Price in $1000s) Predicted Values MEDV')
#plt.savefig('images/10_07.png', dpi=300)
plt.show()

# %% [markdown]
# ## Linear Regression Model input label=LSTAT, output prediction=MEDV

# %% [markdown]
# ### Visualizing the important characteristics of a dataset

# %%
import matplotlib.pyplot as plt
import numpy as np

X = df["RM"]
y = target["MEDV"]

plt.scatter(X, y)
plt.xlabel("LSTAT")
plt.ylabel("MEDV")
plt.legend(loc='upper left')
plt.show()

# %% [raw]
# ### Training the OLS model to predict MEDV on input parameter LSTAT

# %%
import statsmodels.api as sm

X = df["LSTAT"]
y = target["MEDV"]

# Note the difference in argument order
model = sm.OLS(y, X).fit()
predictions = model.predict(X) # make the predictions by the model

# Print out the statistics
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                   MEDV   R-squared:                       0.449
# Model:                            OLS   Adj. R-squared:                  0.448
# Method:                 Least Squares   F-statistic:                     410.9
# Date:                Thu, 25 Oct 2018   Prob (F-statistic):           2.71e-67
# Time:                        13:47:40   Log-Likelihood:                -2182.4
# No. Observations:                 506   AIC:                             4367.
# Df Residuals:                     505   BIC:                             4371.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# LSTAT          1.1221      0.055     20.271      0.000       1.013       1.231
# ...

# %%
X = df["RM"]
y = target["MEDV"]
plt.scatter(X, y, c='grey', edgecolor='white', s=70)
plt.xlabel('True Values')
plt.ylabel('Predictions')
plt.plot(X, model.predict(X), color='black')

# %%
from sklearn.linear_model import LinearRegression

# %%
X = df[['LSTAT']]
y = target['MEDV']

slr = LinearRegression()
slr.fit(X, y)
y_pred = slr.predict(X)
print('Slope: %.3f' % slr.coef_[0])
print('Intercept: %.3f' % slr.intercept_)
# Out:
# Slope: -0.950
# Intercept: 34.554

# %%
plt.scatter(X, y, c='steelblue', edgecolor='white', s=70)
plt.plot(X, y_pred, color='black', lw=2)    
plt.xlabel('(Lower population status) True Values LSTAT')
plt.ylabel('(Price in $1000s) Predicted Values MEDV')
#plt.savefig('images/10_07.png', dpi=300)
plt.show()

# %% [markdown]
# ...

# %% [markdown]
# ## Multiple Linear Regression Model input label=RM, LSTAT, output prediction=MEDV

# %%
import statsmodels.api as sm

X = df[['RM', 'LSTAT']]
y = target['MEDV']
model = sm.OLS(y, X).fit()
predictions = model.predict(X)
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                   MEDV   R-squared:                       0.948
# Model:                            OLS   Adj. R-squared:                  0.948
# Method:                 Least Squares   F-statistic:                     4637.
# Date:                Thu, 25 Oct 2018   Prob (F-statistic):               0.00
# Time:                        13:57:31   Log-Likelihood:                -1582.9
# No. Observations:                 506   AIC:                             3170.
# Df Residuals:                     504   BIC:                             3178.
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# RM             4.9069      0.070     69.906      0.000       4.769       5.045
# ...

# %% [raw]
# ### Multi Linear Regression model with Scikit Learn

# %%
from sklearn import datasets, linear_model
from sklearn.model_selection import train_test_split
from matplotlib import pyplot as plt

X = df[['RM', 'LSTAT']]
y = target['MEDV']
# fit a model
lm = linear_model.LinearRegression()
model = lm.fit(X, y)
predictions = lm.predict(X)
print('Slope: %.3f' % lm.coef_[0])
print('Intercept: %.3f' % lm.intercept_)
# Out:
# Slope: 5.095
# Intercept: -1.358

# %%
print "Score:", model.score(X, y)
# Out:
# Score: 0.6385616062603403

# %%
plt.scatter(y,lm.predict(X) ,  c='steelblue', edgecolor='white', s=70)
#plt.plot(X,lm.predict(X) , color='black', lw=2)  
plt.plot([0,50],[0,50], 'g-')
plt.xlabel('True Values RM + LSTAT')
plt.ylabel('Predicted Values MEDV')
plt.show()

# %% [markdown]
# ## Multiple Linear Regression Model input label=RM, LSTAT, output prediction=MEDV with Holdout Method

# %%
from sklearn import datasets, linear_model
from sklearn.model_selection import train_test_split
from matplotlib import pyplot as plt

# create training and testing vars
X_train, X_test, y_train, y_test = train_test_split(df[['RM', 'LSTAT']], y, test_size=0.2)
print X_train.shape, y_train.shape
print X_test.shape, y_test.shape


# fit a model
lm = linear_model.LinearRegression()
model = lm.fit(X_train, y_train)
predictions = lm.predict(X_test)
# Out:
# (404, 2) (404,)
# (102, 2) (102,)

# %%
predictions[0:20]
# Out:
# array([22.39248208, 29.1653152 , 24.46647188, 12.70977082, 11.79405244,
#         6.87813797, 21.40831489, 15.13468845, 17.68515286, 17.57647174,
#        18.12677115, 15.80435698, 19.95731043, 23.7284898 , 26.26055646,
#        27.72506142, 13.62521602, 23.48444946, 28.04041278, 25.66200995])

# %%
## The line / model

plt.xlabel('True Values')
plt.ylabel('Predictions')

plt.scatter(y_test, predictions , color = 'orange', edgecolor='white', s=70)
plt.legend(loc='upper left')
plt.plot([0,50],[0,50], 'g-')
plt.show()

# %%
print "Score:", model.score(X_test, y_test)
# Out:
# Score: 0.6819392839658802

# %% [markdown]
# ## Rebuild Model from Question1 with addtional predictor TAX

# %%
import statsmodels.api as sm

X = df[['RM', 'LSTAT', 'TAX']]
y = target['MEDV']
model = sm.OLS(y, X).fit()
predictions = model.predict(X)
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                   MEDV   R-squared:                       0.950
# Model:                            OLS   Adj. R-squared:                  0.950
# Method:                 Least Squares   F-statistic:                     3178.
# Date:                Thu, 25 Oct 2018   Prob (F-statistic):               0.00
# Time:                        17:30:17   Log-Likelihood:                -1575.7
# No. Observations:                 506   AIC:                             3157.
# Df Residuals:                     503   BIC:                             3170.
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# RM             5.1312      0.091     56.347      0.000       4.952       5.310
# ...

# %%
from sklearn import datasets, linear_model
import statsmodels.api as sm
X = df[['RM', 'LSTAT', 'TAX']]
y = target['MEDV']
model = lm.fit(X, y)
predictions[0:20]
# Out:
# 0     29.032892
# 1     26.276969
# 2     33.044405
# 3     32.822608
# 4     32.255511
# 5     28.643275
# 6     21.895225
# 7     18.971998
# 8     10.189638
# 9     19.252162
# 10    19.299572
# 11    21.411803
# 12    19.436544
# 13    23.921467
# 14    23.561406
# 15    23.214368
# 16    24.785686
# 17    20.560347
# 18    19.480652
# 19    21.099660
# dtype: float64

# %%
plt.scatter(y, predictions, color = 'orange', edgecolor='white', s=70)
plt.xlabel("RM-LSTAT-TAX- True Values")
plt.ylabel("MEDV - Predicted Values")
plt.legend(loc='upper left')
plt.plot([0,50],[0,50], 'g-')
plt.show()

# %%
print "Score:", model.score(X, y)
# Out:
# Score: 0.6485147669915273

# %% [markdown]
# ###  Polynomial Regression of 2nd degree with input label = LSTAT and output label = MEDV

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn import datasets, linear_model
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge
from sklearn.preprocessing import PolynomialFeatures
from sklearn.pipeline import make_pipeline
from sklearn.metrics import r2_score

X = df[['LSTAT']].values
y = target['MEDV'].values

regr = LinearRegression()
quadratic = PolynomialFeatures(degree=2)
X_quad = quadratic.fit_transform(X)

# fit features
X_fit = np.arange(X.min(), X.max(), 1)[:, np.newaxis]

regr = regr.fit(X_quad, y)
y_quad_fit = regr.predict(quadratic.fit_transform(X_fit))
quadratic_r2 = r2_score(y, regr.predict(X_quad))

plt.scatter(X, y, label='training points', color='lightblue', edgecolor = 'white', s=75)

plt.plot(X_fit, y_quad_fit, 
         label='quadratic (d=2), $R^2=%.2f$' % quadratic_r2,
         color='red', 
         lw=2,
         linestyle='-')

plt.xlabel('% lower status of the population [LSTAT]')
plt.ylabel('Price in $1000s [MEDV]')
plt.legend(loc='upper right')

plt.show()

# %% [markdown]
# ###  Polynomial Regression of 3rd degree with input label = LSTAT and output label = MEDV

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn import datasets, linear_model
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge
from sklearn.preprocessing import PolynomialFeatures
from sklearn.pipeline import make_pipeline
from sklearn.metrics import r2_score

X = df[['LSTAT']].values
y = target['MEDV'].values

regr = LinearRegression()
cubic = PolynomialFeatures(degree=3)
X_cubic = cubic.fit_transform(X)

# fit features
X_fit = np.arange(X.min(), X.max(), 1)[:, np.newaxis]

regr = regr.fit(X_cubic, y)
y_cubic_fit = regr.predict(cubic.fit_transform(X_fit))
cubic_r2 = r2_score(y, regr.predict(X_cubic))

plt.scatter(X, y, label='training points', color='lightblue', edgecolor='white', s=75)

plt.plot(X_fit, y_cubic_fit, 
         label='cubic (d=3), $R^2=%.2f$' % cubic_r2,
         color='green', 
         lw=2, 
         linestyle='--')

plt.xlabel('% lower status of the population [LSTAT]')
plt.ylabel('Price in $1000s [MEDV]')
plt.legend(loc='upper right')

plt.show()
