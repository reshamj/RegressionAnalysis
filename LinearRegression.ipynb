# %% [markdown]
# #HomeWork 2 - CS 483 Data Mining                                           (Resham Jhangiani)

# %% [markdown]
# ## Loading the Housing dataset into a data frame

# %%
import pandas as pd

df = pd.read_csv('https://raw.githubusercontent.com/rasbt/'
                 'python-machine-learning-book-2nd-edition'
                 '/master/code/ch10/housing.data.txt',
                 header=None,
                 sep='\s+')

df.columns = ['CRIM', 'ZN', 'INDUS', 'CHAS', 
              'NOX', 'RM', 'AGE', 'DIS', 'RAD', 
              'TAX', 'PTRATIO', 'B', 'LSTAT', 'MEDV']
df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296.0
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242.0
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242.0
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222.0
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222.0
#
#    PTRATIO       B  LSTAT  MEDV
# 0     15.3  396.90   4.98  24.0
# 1     17.8  396.90   9.14  21.6
# 2     17.8  392.83   4.03  34.7
# 3     18.7  394.63   2.94  33.4
# 4     18.7  396.90   5.33  36.2

# %% [markdown]
# <br>
# <br>

# %% [markdown]
# ## Visualizing the important characteristics of a dataset

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
cols = ['LSTAT','MEDV']

sns.pairplot(df[cols], size=2.5)

plt.tight_layout()
# plt.savefig('images/10_03.png', dpi=300)
plt.show()
# Out:
# /home/resham/anaconda3/envs/dataMining/lib/python2.7/site-packages/seaborn/axisgrid.py:2065: UserWarning: The `size` parameter has been renamed to `height`; pleaes update your code.
#   warnings.warn(msg, UserWarning)

# %%
cols = ['RM', 'MEDV']

sns.pairplot(df[cols], size=2.5)
plt.tight_layout()
# plt.savefig('images/10_03.png', dpi=300)
plt.show()
# Out:
# /home/resham/anaconda3/envs/dataMining/lib/python2.7/site-packages/seaborn/axisgrid.py:2065: UserWarning: The `size` parameter has been renamed to `height`; pleaes update your code.
#   warnings.warn(msg, UserWarning)

# %%
Scatter Plot for RM , MEDV

# %%
import matplotlib.pyplot as plt
import numpy as np

colX = ['RM']
colY = ['MEDV']

plt.scatter(df[colX], df[colY])
plt.xlabel("RM")
plt.ylabel("MEDV")
plt.legend(loc='upper left')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

colX = ['LSTAT']
colY = ['MEDV']

plt.scatter(df[colX], df[colY])
plt.xlabel("LSTAT")
plt.ylabel("MEDV")
plt.legend(loc='upper left')
plt.show()

# %% [markdown]
# <br>
# <br>

# %% [raw]
# ### Load the Boston dataset as pandas data frame. Seperate out the target MEDV into a different pandas dataframe.

# %%
import statsmodels.api as sm
from sklearn import datasets ## imports datasets from scikit-learn
data = datasets.load_boston() ## loads Boston dataset from datasets library 

import numpy as np
import pandas as pd
# define the data/predictors as the pre-set feature names  
df = pd.DataFrame(data.data, columns=data.feature_names)

# Put the target (housing value -- MEDV) in another DataFrame
target = pd.DataFrame(data.target, columns=["MEDV"])

# %% [raw]
# ### Training the OLS model to predict MEDV on input parameter RM

# %%
import statsmodels.api as sm

X = df["RM"]
y = target["MEDV"]

# Note the difference in argument order
model = sm.OLS(y, X).fit()
predictions = model.predict(X) # make the predictions by the model

# Print out the statistics
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                   MEDV   R-squared:                       0.901
# Model:                            OLS   Adj. R-squared:                  0.901
# Method:                 Least Squares   F-statistic:                     4615.
# Date:                Thu, 25 Oct 2018   Prob (F-statistic):          3.74e-256
# Time:                        13:09:13   Log-Likelihood:                -1747.1
# No. Observations:                 506   AIC:                             3496.
# Df Residuals:                     505   BIC:                             3500.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# RM             3.6534      0.054     67.930      0.000       3.548       3.759
# ...

# %%
## The line / model
plt.scatter(y_test, predictions)
plt.xlabel('True Values')
plt.ylabel('Predictions')

# %% [raw]
# ### Training the OLS model to predict MEDV on input parameter RM

# %%
import statsmodels.api as sm

X = df["LSTAT"]
y = target["MEDV"]

# Note the difference in argument order
model = sm.OLS(y, X).fit()
predictions = model.predict(X) # make the predictions by the model

# Print out the statistics
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                   MEDV   R-squared:                       0.449
# Model:                            OLS   Adj. R-squared:                  0.448
# Method:                 Least Squares   F-statistic:                     410.9
# Date:                Thu, 18 Oct 2018   Prob (F-statistic):           2.71e-67
# Time:                        16:03:14   Log-Likelihood:                -2182.4
# No. Observations:                 506   AIC:                             4367.
# Df Residuals:                     505   BIC:                             4371.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# LSTAT          1.1221      0.055     20.271      0.000       1.013       1.231
# ...

# %% [markdown]
# ...

# %% [raw]
# ### Multi Linear Regression model to predict MEDV on input parameters RM and LSTAT

# %%
import statsmodels.api as sm

X = df[['RM', 'LSTAT']]
y = target['MEDV']
model = sm.OLS(y, X).fit()
predictions = model.predict(X)
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                   MEDV   R-squared:                       0.948
# Model:                            OLS   Adj. R-squared:                  0.948
# Method:                 Least Squares   F-statistic:                     4637.
# Date:                Thu, 18 Oct 2018   Prob (F-statistic):               0.00
# Time:                        16:11:55   Log-Likelihood:                -1582.9
# No. Observations:                 506   AIC:                             3170.
# Df Residuals:                     504   BIC:                             3178.
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# RM             4.9069      0.070     69.906      0.000       4.769       5.045
# ...

# %% [raw]
# ### Multi Linear Regression model to predict MEDV on input parameters RM and LSTAT

# %%
from sklearn import datasets, linear_model
from sklearn.model_selection import train_test_split
from matplotlib import pyplot as plt

# # create training and testing vars
# X_train, X_test, y_train, y_test = train_test_split(df[['RM', 'LSTAT']], y, test_size=0.2)
# print X_train.shape, y_train.shape
# print X_test.shape, y_test.shape
X = df[['RM', 'LSTAT']]
y = target['MEDV']
# fit a model
lm = linear_model.LinearRegression()
model = lm.fit(X, y)
predictions = lm.predict(X)

# %%
print "Score:", model.score(X, y)
# Out:
#  Score: 0.6385616062603403

# %% [raw]
# ###Holdout Method - (Test Train set based Linear Regression) For all 13 independent varaibles.

# %%
from sklearn import datasets, linear_model
from sklearn.model_selection import train_test_split
from matplotlib import pyplot as plt

# create training and testing vars
X_train, X_test, y_train, y_test = train_test_split(df, y, test_size=0.2)
print X_train.shape, y_train.shape
print X_test.shape, y_test.shape


# fit a model
lm = linear_model.LinearRegression()
model = lm.fit(X_train, y_train)
predictions = lm.predict(X_test)
# Out:
# (404, 13) (404,)
# (102, 13) (102,)

# %%
predictions[0:20]
# Out:
# array([20.56106454, 18.47147261, 23.69436988, 22.2914615 , 17.05543263,
#        12.55678908, 25.06243996, 23.85014016, 16.60011394, 11.60410648,
#        28.7519006 , 32.90543923, 37.26189953, 25.54999015, 20.73297315,
#         3.52464356, 32.82901862, 33.91247105, 13.94653259, 35.69259223])

# %%
## The line / model
plt.scatter(y_test, predictions)
plt.xlabel('True Values')
plt.ylabel('Predictions')
# Out:
# Text(0,0.5,'Predictions')

# %%
print "Score:", model.score(X_test, y_test)
# Out:
# Score: 0.7350497833420166

# %% [raw]
# ###Holdout Method - (Test Train set based Linear Regression) For RM and LSTAT independent varaibles.

# %%
from sklearn import datasets, linear_model
from sklearn.model_selection import train_test_split
from matplotlib import pyplot as plt

# create training and testing vars
X_train, X_test, y_train, y_test = train_test_split(df[['RM', 'LSTAT']], y, test_size=0.2)
print X_train.shape, y_train.shape
print X_test.shape, y_test.shape


# fit a model
lm = linear_model.LinearRegression()
model = lm.fit(X_train, y_train)
predictions = lm.predict(X_test)
# Out:
# (404, 2) (404,)
# (102, 2) (102,)

# %%
predictions[0:20]
# Out:
# array([11.29254985,  3.80335964, 19.7749239 , 29.56843557, 24.10234695,
#        20.39233524, 23.8520058 , 16.07579895, -3.36087953, 33.12639793,
#        16.015716  , 38.00036319,  3.72446009, 16.98431812, 21.52806253,
#         4.5488394 , 38.41381919, 19.77575101, 19.73598908,  2.79409251])

# %%
## The line / model
plt.scatter(y_test, predictions)
plt.xlabel('True Values')
plt.ylabel('Predictions')

plt.scatter(y_test, predictions)
plt.legend(loc='upper left')
plt.plot([0,50],[0,50], 'g-')
plt.show()

# %%
print "Score:", model.score(X_test, y_test)
# Out:
# Score: 0.5836397156007084

# %% [raw]
# ###Question 2 Rebuild the Multi linear regression model with new added parameter. Using the OLS Model

# %%
import statsmodels.api as sm

X = df[['RM', 'LSTAT', 'TAX']]
y = target['MEDV']
model = sm.OLS(y, X).fit()
predictions = model.predict(X)
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                   MEDV   R-squared:                       0.950
# Model:                            OLS   Adj. R-squared:                  0.950
# Method:                 Least Squares   F-statistic:                     3178.
# Date:                Thu, 18 Oct 2018   Prob (F-statistic):               0.00
# Time:                        18:59:31   Log-Likelihood:                -1575.7
# No. Observations:                 506   AIC:                             3157.
# Df Residuals:                     503   BIC:                             3170.
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# RM             5.1312      0.091     56.347      0.000       4.952       5.310
# ...

# %% [raw]
# ###Question 2 Rebuild the Multi linear regression model with new added parameter. Using the Linear Regression Model from sklearn

# %%
from sklearn import datasets, linear_model
import statsmodels.api as sm
X = df[['RM', 'LSTAT', 'TAX']]
y = target['MEDV']
model = lm.fit(X, y)
predictions[0:20]
# Out:
# 0     29.857643
# 1     25.421326
# 2     32.704867
# 3     31.559278
# 4     31.313877
# 5     26.896444
# 6     22.735090
# 7     20.428409
# 8     11.748020
# 9     20.387940
# 10    21.068812
# 11    22.303158
# 12    20.353708
# 13    21.078858
# 14    21.012813
# 15    20.257576
# 16    21.817854
# 17    18.181713
# 18    16.313661
# 19    18.207283
# dtype: float64

# %%
plt.scatter(y, predictions)
plt.xlabel('True Values')
plt.ylabel('Predictions')
# Out:
# Text(0,0.5,'Predictions')

# %%
print "Score:", model.score(X, y)
# Out:
# Score: 0.6485147669915273

# %%
import statsmodels.api as sm
from matplotlib import pyplot as plt
import seaborn as sns

X = df[['RM', 'LSTAT', 'PTRATIO']]
y = target['MEDV']
model = sm.OLS(y, X).fit()
predictions = model.predict(X)
model.summary()

plt.scatter(y, predictions)
plt.xlabel("RM-LSTAT-TAX")
plt.ylabel("MEDV")
plt.legend(loc='upper left')
plt.plot([0,50],[0,50], 'g-')
plt.show()

# %% [raw]
# Polynomial Regression (2 nd degree) for Boston Housing data

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn import datasets, linear_model
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge
from sklearn.preprocessing import PolynomialFeatures
from sklearn.pipeline import make_pipeline
from sklearn.metrics import r2_score

X = df[['LSTAT']].values
y = target['MEDV'].values

regr = LinearRegression()
quadratic = PolynomialFeatures(degree=2)
X_quad = quadratic.fit_transform(X)

regr = regr.fit(X_quad, y)
y_quad_fit = regr.predict(quadratic.fit_transform(X_fit))
quadratic_r2 = r2_score(y, regr.predict(X_quad))

plt.scatter(X, y, label='training points', color='lightgray')

plt.plot(X_fit, y_quad_fit, 
         label='quadratic (d=2), $R^2=%.2f$' % quadratic_r2,
         color='red', 
         lw=2,
         linestyle='-')

plt.xlabel('% lower status of the population [LSTAT]')
plt.ylabel('Price in $1000s [MEDV]')
plt.legend(loc='upper right')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-6e5a7f6bbae4> in <module>()
#      17
#      18 regr = regr.fit(X_quad, y)
# ---> 19 y_quad_fit = regr.predict(quadratic.fit_transform(X_fit))
#      20 quadratic_r2 = r2_score(y, regr.predict(X_quad))
#      21
#
# NameError: name 'X_fit' is not defined

# %% [raw]
# Polynomial Regression (3 rd degree) for Boston Housing data

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn import datasets, linear_model
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge
from sklearn.preprocessing import PolynomialFeatures
from sklearn.pipeline import make_pipeline
from sklearn.metrics import r2_score

X = df[['LSTAT']].values
y = target['MEDV'].values

regr = LinearRegression()
cubic = PolynomialFeatures(degree=3)
X_cubic = cubic.fit_transform(X)

regr = regr.fit(X_cubic, y)
y_cubic_fit = regr.predict(cubic.fit_transform(X_fit))
cubic_r2 = r2_score(y, regr.predict(X_cubic))

plt.scatter(X, y, label='training points', color='lightgray')

plt.plot(X_fit, y_cubic_fit, 
         label='cubic (d=3), $R^2=%.2f$' % cubic_r2,
         color='green', 
         lw=2, 
         linestyle='--')

plt.xlabel('% lower status of the population [LSTAT]')
plt.ylabel('Price in $1000s [MEDV]')
plt.legend(loc='upper right')

plt.show()

# %% [raw]
# Comparing Linear Regressio and Polynomial Regression (2-3 degree) for Boston Housing data

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn import datasets, linear_model
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge
from sklearn.preprocessing import PolynomialFeatures
from sklearn.pipeline import make_pipeline
from sklearn.metrics import r2_score

X = df[['LSTAT']].values
y = target['MEDV'].values

regr = LinearRegression()

# create quadratic features
quadratic = PolynomialFeatures(degree=2)
cubic = PolynomialFeatures(degree=3)
X_quad = quadratic.fit_transform(X)
X_cubic = cubic.fit_transform(X)

# fit features
X_fit = np.arange(X.min(), X.max(), 1)[:, np.newaxis]

regr = regr.fit(X, y)
y_lin_fit = regr.predict(X_fit)
linear_r2 = r2_score(y, regr.predict(X))

regr = regr.fit(X_quad, y)
y_quad_fit = regr.predict(quadratic.fit_transform(X_fit))
quadratic_r2 = r2_score(y, regr.predict(X_quad))

regr = regr.fit(X_cubic, y)
y_cubic_fit = regr.predict(cubic.fit_transform(X_fit))
cubic_r2 = r2_score(y, regr.predict(X_cubic))


# plot results
plt.scatter(X, y, label='training points', color='orange', edgecolor='white', s=75)

plt.plot(X_fit, y_lin_fit, 
         label='linear (d=1), $R^2=%.2f$' % linear_r2, 
         color='blue', 
         lw=2, 
         linestyle=':')

plt.plot(X_fit, y_quad_fit, 
         label='quadratic (d=2), $R^2=%.2f$' % quadratic_r2,
         color='red', 
         lw=2,
         linestyle='-')

plt.plot(X_fit, y_cubic_fit, 
         label='cubic (d=3), $R^2=%.2f$' % cubic_r2,
         color='green', 
         lw=2, 
         linestyle='--')

plt.xlabel('True Values ')
plt.ylabel('Predicted [MEDV] values')
plt.legend(loc='upper right')

#plt.savefig('images/10_11.png', dpi=300)
plt.show()

# %% [raw]
# Polynomial Regression (2-3 degree) using Holdout method.

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn import datasets, linear_model
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge
from sklearn.preprocessing import PolynomialFeatures
from sklearn.pipeline import make_pipeline

X = df[['LSTAT']]
y = target[['MEDV']]

x_training_set, x_test_set, y_training_set, y_test_set = train_test_split(X,y,test_size=0.10, 
                                                                          random_state=42,
                                                                          shuffle=True)

plt.scatter(x_test_set, y_test_set, s=10, alpha=0.3)


for degree in [1,2,3]:

    model = make_pipeline(PolynomialFeatures(degree), LinearRegression())

    model.fit(x_training_set,y_training_set)

    y_plot = model.predict(x_test_set)

    plt.plot(x_test_set, y_plot, label="degree %d" % degree

             +'; $R^2$: %.2f' % model.score(x_test_set, y_test_set))

plt.legend(loc='upper right')

plt.xlabel("Test LSTAT Data")

plt.ylabel("Predicted Price")

plt.title("Variance Explained with Varying Polynomial")

plt.show()

# %%
model.score(x_test_set, y_test_set)
# Out:
# 0.7058214030330693
